# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame 
import nltk

from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

import re
import string
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_json("Office_Products_5.json", lines=True)
print(df.columns)
print(df.shape)
# Out:
# Index([u'asin', u'helpful', u'overall', u'reviewText', u'reviewTime',
#        u'reviewerID', u'reviewerName', u'summary', u'unixReviewTime'],
#       dtype='object')
# (53258, 9)

# %%
df_required = df[['asin', 'reviewerID', 'overall']]
df_required
# Out:
#              asin             reviewerID  overall
# 0      B004APM26Q  A00473363TJ8YSZ3YAGG9        5
# 1      B0073W70BK  A00473363TJ8YSZ3YAGG9        4
# 2      B007ZYF266  A00473363TJ8YSZ3YAGG9        4
# 3      B00007E7D2  A00473363TJ8YSZ3YAGG9        2
# 4      B00D51XMLU  A00473363TJ8YSZ3YAGG9        4
# 5      B0006HXAW2  A04324702R5O7JRSQNVAH        5
# 6      B00004Z5SN  A04324702R5O7JRSQNVAH        5
# 7      B0009F3P3U  A04324702R5O7JRSQNVAH        5
# 8      B001BLZDKE  A04324702R5O7JRSQNVAH        5
# 9      B003RL7RRS  A04324702R5O7JRSQNVAH        5
# 10     B00007M5KZ   A0678500JUN3N7KUG4PS        5
# 11     B002ECFILI   A0678500JUN3N7KUG4PS        5
# 12     B009MPB9KY   A0678500JUN3N7KUG4PS        5
# 13     B0017D5YW8   A0678500JUN3N7KUG4PS        5
# 14     B004ZDL0K2   A0678500JUN3N7KUG4PS        5
# 15     B000E7AIA6   A0678500JUN3N7KUG4PS        5
# 16     B0013CQ20Q   A0678500JUN3N7KUG4PS        5
# 17     B0009F3P3U         A100UD67AHFODS        5
# 18     B00006RSP1         A100UD67AHFODS        5
# 19     B001MS6XW8         A100UD67AHFODS        5
# 20     B000S161FO         A100UD67AHFODS        5
# 21     B00BBLORGK         A100UD67AHFODS        4
# 22     B0035FX5MC         A100WO06OQR8BQ        5
# 23     B003H04A42         A100WO06OQR8BQ        5
# 24     B003BHLMMY         A100WO06OQR8BQ        5
# 25     B005VC8CG6         A100WO06OQR8BQ        5
# 26     B005ETZIPE         A100WO06OQR8BQ        3
# 27     B002HI9RKM         A100WO06OQR8BQ        5
# 28     B002K9M8RC         A100WO06OQR8BQ        5
# 29     B007ZLALUG         A100WO06OQR8BQ        5
# ...           ...                    ...      ...
# 53228  B001PM6RX6          AZU2JDR2GVICQ        3
# 53229  B00001MXVQ          AZU2JDR2GVICQ        1
# 53230  B0033UU1J4          AZYJE40XW6MFG        1
# 53231  B004M27EOW          AZYJE40XW6MFG        4
# 53232  B00FA4MP5O          AZYJE40XW6MFG        4
# 53233  B004U9TEEA          AZYJE40XW6MFG        5
# 53234  B002E3AI0I          AZYJE40XW6MFG        4
# 53235  B0006HVPTW          AZYJE40XW6MFG        5
# 53236  B000DZAT12          AZYJE40XW6MFG        5
# 53237  B000E27UIE          AZYJE40XW6MFG        5
# 53238  B00347A8GC          AZYJE40XW6MFG        5
# 53239  B003XDU8O4          AZYJE40XW6MFG        5
# 53240  B0039N3QO2          AZYJE40XW6MFG        5
# 53241  B0061ZPD00          AZZ5ASC403N74        5
# 53242  B008CO4NCC          AZZ5ASC403N74        4
# 53243  B004M27EOW          AZZ5ASC403N74        4
# 53244  B000J07BRQ          AZZ5ASC403N74        5
# 53245  B00A87XIZY          AZZ5ASC403N74        5
# 53246  B00AVWKUJI          AZZ5ASC403N74        4
# 53247  B004YGBIVQ          AZZ5ASC403N74        5
# 53248  B00G4TYP7K          AZZ5ASC403N74        5
# 53249  B00G4TYQ9W          AZZ5ASC403N74        5
# 53250  B0045Z4PGQ          AZZ5ASC403N74        5
# 53251  B005IMARK8          AZZ5ASC403N74        4
# 53252  B006Y9H0UE          AZZ5ASC403N74        4
# 53253  B000SAF07K          AZZD30PYJVGI7        4
# 53254  B004W7IOV4          AZZD30PYJVGI7        5
# 53255  B00125Q75Y          AZZD30PYJVGI7        5
# 53256  B004I9CZ2U          AZZD30PYJVGI7        5
# 53257  B000VKUXHY          AZZD30PYJVGI7        5
#
# [53258 rows x 3 columns]

# %%
df_train = df_required.groupby('reviewerID').apply(lambda x: int(len(x)*0.8))
df_train
# Out:
# reviewerID
# A00473363TJ8YSZ3YAGG9     4
# A04324702R5O7JRSQNVAH     4
# A0678500JUN3N7KUG4PS      5
# A100UD67AHFODS            4
# A100WO06OQR8BQ           36
# A100ZQDV7L8PVV            4
# A101PIL0I3UZJJ            4
# A1027EV8A9PV1O            7
# A1047EDJ84IMAS            4
# A105S56ODHGJEK           16
# A106MB2IVYFRWR            4
# A106Q1A6LGU4DP           10
# A107H3XGCV6Y4Q            6
# A108B8OUQ0GHNF            4
# A10AQSHGUSJM5Q            4
# A10ASLX7DTTB6Z           10
# A10C4O0Q0TWXOL            4
# A10C5CJK1YKGV0            5
# A10E3F50DIUJEE            4
# A10ERSEFIAHESG            5
# A10G4BPT5MGBHY           14
# A10H24TDLK2VDP            8
# A10IFEQER9UA7T            4
# A10J0IVZ97LYJ9            4
# A10JPZAYDGFHEV            4
# A10KBYZJ0P3MPQ            4
# A10M2MLE2R0L6K            4
# A10O7THJ2O20AG            8
# A10PEXB6XAQ5XF            8
# A10Q2ZCYPEVHCU            5
#                          ..
# AZ74PFI67BCG2             4
# AZ8XSDMIX04VJ            12
# AZ9WQM7SLUX7E            16
# AZA55FJD7CCZN             5
# AZA595ZPIG240             4
# AZAC8O310IK4E            10
# AZAKCIFE27RAA            13
# AZBXKUH4AIW3X             8
# AZD7C4ZW00YKH             4
# AZD8SMNGQI98O            17
# AZE2ZP618W1EP             4
# AZF7A44AW3K0I             4
# AZFHSPEZUPGD2             8
# AZGGG49I1J5E5             5
# AZH419IZOWETK             4
# AZIJ44I4NIO5M             5
# AZJFLPEG7D09G             4
# AZKGCE3LNX7WB            19
# AZL1JK2B50D2H             4
# AZMISC9FAUBIR            10
# AZMY6E8B52L2T            16
# AZNUHQSHZHSUE            11
# AZO8OJ7YGSJSS             4
# AZQAEL5GPBNIR             4
# AZQGJ5CEAJGXB             6
# AZQJ85BTRUQV2             5
# AZU2JDR2GVICQ             4
# AZYJE40XW6MFG             8
# AZZ5ASC403N74             9
# AZZD30PYJVGI7             4
# Length: 4905, dtype: int64
